# %% [markdown]
# 35 means #, 46 means ., 10 starts a new line of output below the current one, and so on. (Within a line, characters are drawn left-to-right.)
# /# represents a scaffold
# /. represents open space
# The vacuum robot is visible as ^, v, <, or >
# /X: robot tumbling through space uncontrollably
#
# Locate all scaffold intersections; for each, its alignment parameter is the distance between its left edge and the left edge of the view multiplied by the distance between its top edge and the top edge of the view. Here, the intersections from the above image are marked O.
# To calibrate the cameras, you need the sum of the alignment parameters. In the above example, this is 76.
#
# str(chr(10))

# %%
import utils as u
import numpy as np
import itertools

class Point:
    def __init__(self,x,y):
        self.x=x
        self.y=y

# %%
ic_org=u.get_input('day17.txt').split(',')
ic_org=[int(x) for x in ic_org]
ic=ic_org.copy()+[0]*27000

# %%
out=[]
inn=rb=i=0
output=0
while output != 99:
    (output,ic,i,rb)=u.Intcode(inn,ic,i,rb)
    out.append(output)

# %% [markdown]
# txt=[str(chr(x)) for x in out]
# tekst=''
# for x in txt:
#     tekst+=x
# map=tekst.split('\n')
# map=map[:-2]
# map

# %%
txt=[str(chr(x)) for x in out]

# %%
for i in range(txt.count('\n')):
    txt.remove('\n')
A=np.array(txt[:-1])
map=np.reshape(A,(53,-1),order='F').transpose()
map
# Out:
# array([['.', '.', '.', ..., '.', '.', '.'],
#        ['.', '.', '.', ..., '.', '.', '.'],
#        ['.', '.', '.', ..., '.', '.', '.'],
#        ...,
#        ['.', '.', '.', ..., '.', '.', '.'],
#        ['.', '.', '.', ..., '.', '.', '.'],
#        ['.', '.', '.', ..., '.', '.', '.']], dtype='<U1')

# %%
answer=0
for i,j in itertools.product(range(1,map.shape[0]-1),range(1,map.shape[1]-1)):
    if map[i,j]=='#' and map[i+1,j]==map[i-1,j]==map[i,j+1]==map[i,j-1]=='#':
        answer+=i*j
print(answer)
# Out:
# 12512

# %% [markdown]
# # Part 2:
# - First, you will be prompted for the main movement routine. Functions: A, B, or C.
# - Then in order: A,B,C define the movement functions
# - Finally, you will be asked whether you want to see a continuous video feed; provide either y or n and a newline.
#
# Supply the movement functions to use as ASCII text, separating them with commas (',' ASCII code 44), and ending the list with a newline (ASCII code 10).
# Movement functions may use L to turn left, R to turn right, or a number to move forward that many units.
# Due to the limited amount of memory in the vacuum robot, the ASCII definitions of the main routine and the movement functions may each contain at most 20 characters, not counting the newline.

# %%
dic={'main':'A,B,A,C,B,C,B,C,A,C',
    'A':'R,12,L,10,R,12',
    'B':'L,8,R,10,R,6',
    'C':'R,12,L,10,R,10,L,8',
    'D':'n'}

# %%
inn=[]
for key in dic:
    inn+=[ord(x) for x in dic[key]]+[10]

# %%
ic2=ic_org.copy()
ic2[0]=2

# %%
vm=u.Acii(ic2)

# %%
vm.addqueue(inn)

# %%
out=[]
output=1
while output != [99]:
    output=vm.update()
    out.append(output)

# %%
out
# Out:
# [[46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   35,
#   35,
#   35,
#   35,
#   35,
#   35,
#   35,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   10],
#  [46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   35,
#   46,
#   46,
#   46,
#   46,
#   46,
#   35,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   10],
#  [46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   46,
#   35,
#   46,
# ...

# %%
len(vm.queue)

# %%
u=vm.update()
u
